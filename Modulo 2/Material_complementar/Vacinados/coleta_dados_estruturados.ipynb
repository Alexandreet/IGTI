# %% [markdown]
# # Coleta de dados estruturados
#
# Os dados estruturados são provenientes de estruturas definidas, inflexível, pensadas antes mesmo da própria criação dos dados. Exemplo de dados estruturados: Tabelas de banco de dados, planilhas eletrônicas, arquivos de textos como txt e csv.
#
# Nesse exercício vamos inicíar a coleta de dados proveniente de arquivos de texto disponibilizado no site do Kaggle.
#
# A base de dados está disponível no seguinte link: https://www.kaggle.com/gpreda/covid-world-vaccination-progress
#
# **Informação importante:**
# Esse dataset é atualizado diariamente. Desta forma, para que os resultados sejam iguais esse exercicio, temos que utilizar o mesmo dataset. O dataset pode ser obtido no arquivo disponbilizado da plataforma do canvas do IGTI ou no github https://github.com/ProfLeandroLessa
#
# O dataset utilizado nesse estudo foi coletado no dia 26/02/2021 às 17:50

# %%
# Antes de iniciar a coleta dos dados vamos importar as bibliotecas necessárias.
import pandas as pd
import os

# %% [markdown]
# # Importando dados do arquivo
# O primeiro passo é encontrar o local aonde o arquivo a ser trabalho vai estar armazenado.
# Após isso, vamos abrir-lo e em seguida vamos adiciona-lo dentro de um dataframe do pandas.

# %%
DIRETORIO = '/Users/macbook/Documents/Projects Github/IGTI/Modulo 2/Material_complementar/Vacinados/dataset/'
arquivo = 'country_vaccinations.csv'
dados = os.path.join(DIRETORIO, arquivo) # busca caminho do arquivo ja com suas conversões

# %% [markdown]
# Verifica o caminho do diretorio que o arquivo esta salvo

# %%
dados
# Out:
# '/Users/macbook/Documents/Projects Github/IGTI/Modulo 2/Material_complementar/Vacinados/dataset/country_vaccinations.csv'

# %% [markdown]
# Agora vamos criar um data frame no pandas e ler o arquivo na pasta de origem.
# Para abir o arquivo vamos utilizar o comando read_csv e utiliar o separador ';' de acordo com o dado fornecido. Além disso, temos que utilizar o encoding informando a codigicação do arquivo.

# %%
dataframe = pd.read_csv(dados, sep=',', encoding='latin-1')

# %%
# Exibe os 5 primeiros regirstros da tabela
dataframe.head(5)
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                           0.00
# 1                             NaN                            NaN
# 2                            0.00                           0.00
# 3                            0.01                           0.01
# 4                            0.01                           0.01
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            22.0
# 2                                  NaN                            22.0
# 3                                  NaN                            22.0
# 4                                  NaN                            23.0
#
#           vaccines         source_name  \
# 0  Pfizer/BioNTech  Ministry of Health
# 1  Pfizer/BioNTech  Ministry of Health
# 2  Pfizer/BioNTech  Ministry of Health
# 3  Pfizer/BioNTech  Ministry of Health
# 4  Pfizer/BioNTech  Ministry of Health
#
#                                       source_website
# 0  https://shendetesia.gov.al/covid19-ministria-e...
# 1  https://shendetesia.gov.al/covid19-ministria-e...
# 2  https://shendetesia.gov.al/covid19-ministria-e...
# 3  https://shendetesia.gov.al/covid19-ministria-e...
# 4  https://shendetesia.gov.al/covid19-ministria-e...

# %% [markdown]
# # Analisando os dados
#
#
# ## Sobre o dataset
#
# O dataset utilizado é referente a estatistica do número de vacinados da COVID-19 em todos os países do mundo.
#
# Para esse estudo vamos utilizar as váriaveis:
# *country = pais;
# date = data;
# total_vaccinations = Número total de vacinações ( número absoluto de imunizações totais no país);
# daily_vaccinations = Número de vacinados por dia;
# Vaccines = vacinas utilizadas no país;
# ;*
#
#
# Vamos responder as perguntas:
#
# 1. Quais são os países com maior número de pessoas imunizadas?
# 2. Qual vacina é a mais utilizada no mundo? ** Existem diferentes tipos de vacinas disponível no mundo
# 3. Qual a país possui o maior número de vacinados por dia?
# 4. Qual a média de vacinação de vacinação por pais?
#
# Após responder as perguntas vamos exportar as respostas obtidas.

# %%
# Verificando dados referênte ao brasil por dia.
dataframe.query('country == "Brazil" ').sort_values('date', ascending=False)[:5]
# Out:
#     country iso_code        date  total_vaccinations  people_vaccinated  \
# 573  Brazil      BRA  2021-02-26           8101787.0          6346769.0
# 572  Brazil      BRA  2021-02-25           7799000.0          6202055.0
# 571  Brazil      BRA  2021-02-24           7551676.0          6116082.0
# 570  Brazil      BRA  2021-02-23           7297061.0          6002873.0
# 569  Brazil      BRA  2021-02-22           7028356.0          5857080.0
#
#      people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 573                1755018.0                302787.0            223804.0
# 572                1596945.0                247324.0            227474.0
# 571                1435594.0                254615.0            238305.0
# 570                1294188.0                268705.0            241018.0
# 569                1171276.0                 77554.0            247768.0
#
#      total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 573                            3.81                           2.99
# 572                            3.67                           2.92
# 571                            3.55                           2.88
# 570                            3.43                           2.82
# 569                            3.31                           2.76
#
#      people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 573                                 0.83                          1053.0
# 572                                 0.75                          1070.0
# 571                                 0.68                          1121.0
# 570                                 0.61                          1134.0
# 569                                 0.55                          1166.0
#
#                         vaccines                                  source_name  \
# 573  Oxford/AstraZeneca, Sinovac  Regional governments via Coronavirus Brasil
# 572  Oxford/AstraZeneca, Sinovac  Regional governments via Coronavirus Brasil
# 571  Oxford/AstraZeneca, Sinovac  Regional governments via Coronavirus Brasil
# 570  Oxford/AstraZeneca, Sinovac  Regional governments via Coronavirus Brasil
# 569  Oxford/AstraZeneca, Sinovac  Regional governments via Coronavirus Brasil
#
#                          source_website
# 573  https://coronavirusbra1.github.io/
# 572  https://coronavirusbra1.github.io/
# 571  https://coronavirusbra1.github.io/
# 570  https://coronavirusbra1.github.io/
# 569  https://coronavirusbra1.github.io/

# %%
# verificando o número de países distintos na base
dataframe['country'].nunique()
# Out:
# 112

# %%
# verificando número de linhas, colunas do df
dataframe.shape
# Out:
# (4380, 15)

# %% [markdown]
# **Observem que temos 112 registros de países no nosso dataset**

# %% [markdown]
# ## 1. Qual o pais com maior número de pessoas imunizadas?
#
# Para que a análise seja realizada de forma correta é necessário analisar profundamente os dados.
# Nessa etapa, precisamos fazer vários testes afim de conhecer melhor os dados.
# Perceba que o dataset traz infomação por data de coleta. Dessa forma, temos que filtrar o ultimo registro baseado na data.
#
# Será que essa análise é correta?
#
# Vamos analisar!

# %%
#identificando a data mais recente da coleta
ultima_data = dataframe['date'].max()
ultima_data
# Out:
# '2021-02-26'

# %%
# filtrando a ultima data
ultima_data = dataframe[dataframe.date == ultima_data]

# %%
# O comando shape mostra a quantidade de linhas e colunas dentro de um dataset
ultima_data.shape
# Out:
# (43, 15)

# %%
# Verificando o Cabeçalho do ultima_data errado
ultima_data.head(43)
# Out:
#                    country iso_code        date  total_vaccinations  \
# 170              Argentina      ARG  2021-02-26            903915.0
# 182              Australia      AUS  2021-02-26             23504.0
# 230                Austria      AUT  2021-02-26            620919.0
# 317                Bahrain      BHR  2021-02-26            292917.0
# 573                 Brazil      BRA  2021-02-26           8101787.0
# 633               Bulgaria      BGR  2021-02-26            204439.0
# 700                 Canada      CAN  2021-02-26           1778405.0
# 827                  Chile      CHL  2021-02-26           3345027.0
# 895               Colombia      COL  2021-02-26             81333.0
# 1122               Czechia      CZE  2021-02-26            644321.0
# 1470               Finland      FIN  2021-02-26            426806.0
# 1593               Germany      DEU  2021-02-26           5910537.0
# 1701                Greece      GRC  2021-02-26            857306.0
# 1806               Hungary      HUN  2021-02-26            808008.0
# 1865               Iceland      ISL  2021-02-26             32157.0
# 1908                 India      IND  2021-02-26          13756940.0
# 1954             Indonesia      IDN  2021-02-26           2449451.0
# 2056           Isle of Man      IMN  2021-02-26             19884.0
# 2126                Israel      ISR  2021-02-26           7957787.0
# 2188                 Italy      ITA  2021-02-26           4074575.0
# 2198                 Japan      JPN  2021-02-26             28530.0
# 2359                Latvia      LVA  2021-02-26             60732.0
# 2373               Lebanon      LBN  2021-02-26             24637.0
# 2476             Lithuania      LTU  2021-02-26            234959.0
# 2570              Maldives      MDV  2021-02-26             99419.0
# 2699                Mexico      MEX  2021-02-26           2271032.0
# 2726            Montenegro      MNE  2021-02-26              1113.0
# 2756               Morocco      MAR  2021-02-26           3424295.0
# 3192                Poland      POL  2021-02-26           3269812.0
# 3254              Portugal      PRT  2021-02-26            797005.0
# 3374               Romania      ROU  2021-02-26           1506033.0
# 3485          Saudi Arabia      SAU  2021-02-26            639587.0
# 3614                Serbia      SRB  2021-02-26           1393086.0
# 3755              Slovakia      SVK  2021-02-26            433998.0
# 3817              Slovenia      SVN  2021-02-26            171605.0
# 3828          South Africa      ZAF  2021-02-26             63648.0
# 3830           South Korea      KOR  2021-02-26             18489.0
# 3974                Sweden      SWE  2021-02-26            720631.0
# 4059                Turkey      TUR  2021-02-26           8298805.0
# 4092               Ukraine      UKR  2021-02-26              3051.0
# 4145  United Arab Emirates      ARE  2021-02-26           5933299.0
# 4289         United States      USA  2021-02-26          70454064.0
# 4379              Zimbabwe      ZWE  2021-02-26             12579.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 170            620635.0                 283280.0                 74083.0
# 182             23504.0                      NaN                  6881.0
# 230                 NaN                      NaN                 38784.0
# 317            292917.0                      NaN                  2814.0
# 573           6346769.0                1755018.0                302787.0
# 633            167258.0                  37181.0                 15927.0
# 700                 NaN                      NaN                 67180.0
# 827           3289086.0                  55941.0                 71244.0
# 895             81333.0                      NaN                 15176.0
# 1122           406410.0                 237911.0                 17761.0
# 1470           347082.0                  79724.0                 29945.0
# 1593          3881490.0                2029047.0                164222.0
# 1701           556380.0                 300926.0                 30936.0
# 1806           563601.0                 244407.0                 46103.0
# 1865            19593.0                  12564.0                   706.0
# 1908         11552857.0                2204083.0                689893.0
# 1954          1583581.0                 865870.0                133786.0
# 2056            13600.0                   6284.0                  1089.0
# 2126          4663028.0                3294759.0                 33364.0
# 2188          2696588.0                1377987.0                114071.0
# 2198            28530.0                      NaN                  6634.0
# 2359            43743.0                  16989.0                  2660.0
# 2373                NaN                      NaN                   804.0
# 2476           162148.0                  72811.0                  9309.0
# 2570                NaN                      NaN                  1108.0
# 2699          1708721.0                 562311.0                182219.0
# 2726             1113.0                      NaN                     NaN
# 2756          3327858.0                  96437.0                220190.0
# 3192          2101754.0                1168058.0                     NaN
# 3254           538636.0                 258369.0                 44688.0
# 3374           890068.0                 615965.0                 19125.0
# 3485                NaN                      NaN                     NaN
# 3614           886086.0                 507000.0                 17214.0
# 3755           301488.0                 132510.0                 14423.0
# 3817           120377.0                  51228.0                  7198.0
# 3828            63648.0                  63648.0                 11001.0
# 3830            18489.0                      NaN                 18489.0
# 3974           474028.0                 246603.0                 30360.0
# 4059          6745147.0                1553658.0                319079.0
# 4092             3051.0                      NaN                  1713.0
# 4145                NaN                      NaN                 87263.0
# 4289         47184199.0               22613359.0               2179947.0
# 4379            12579.0                      NaN                  1572.0
#
#       daily_vaccinations  total_vaccinations_per_hundred  \
# 170              33609.0                            2.00
# 182               3358.0                            0.09
# 230              19147.0                            6.89
# 317               3521.0                           17.21
# 573             223804.0                            3.81
# 633              14310.0                            2.94
# 700              53507.0                            4.71
# 827              64996.0                           17.50
# 895               8575.0                            0.16
# 1122             14056.0                            6.02
# 1470             13311.0                            7.70
# 1593            143996.0                            7.05
# 1701             27566.0                            8.23
# 1806             29709.0                            8.36
# 1865               920.0                            9.42
# 1908            472428.0                            1.00
# 1954             82443.0                            0.90
# 2056               391.0                           23.38
# 2126            113721.0                           91.94
# 2188             95384.0                            6.74
# 2198              3356.0                            0.02
# 2359              2320.0                            3.22
# 2373              1967.0                            0.36
# 2476              6685.0                            8.63
# 2570              5053.0                           18.39
# 2699             99553.0                            1.76
# 2726               186.0                            0.18
# 2756            151735.0                            9.28
# 3192             87005.0                            8.64
# 3254             25481.0                            7.82
# 3374             26811.0                            7.83
# 3485             17337.0                            1.84
# 3614             33145.0                           20.47
# 3755             10674.0                            7.95
# 3817              4090.0                            8.25
# 3828              8161.0                            0.11
# 3830             18489.0                            0.04
# 3974             19255.0                            7.14
# 4059            276729.0                            9.84
# 4092              1446.0                            0.01
# 4145             66638.0                           59.99
# 4289           1552717.0                           21.07
# 4379              1750.0                            0.08
#
#       people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 170                            1.37                                 0.63
# 182                            0.09                                  NaN
# 230                             NaN                                  NaN
# 317                           17.21                                  NaN
# 573                            2.99                                 0.83
# 633                            2.41                                 0.54
# 700                             NaN                                  NaN
# 827                           17.21                                 0.29
# 895                            0.16                                  NaN
# 1122                           3.80                                 2.22
# 1470                           6.26                                 1.44
# 1593                           4.63                                 2.42
# 1701                           5.34                                 2.89
# 1806                           5.83                                 2.53
# 1865                           5.74                                 3.68
# 1908                           0.84                                 0.16
# 1954                           0.58                                 0.32
# 2056                          15.99                                 7.39
# 2126                          53.87                                38.07
# 2188                           4.46                                 2.28
# 2198                           0.02                                  NaN
# 2359                           2.32                                 0.90
# 2373                            NaN                                  NaN
# 2476                           5.96                                 2.67
# 2570                            NaN                                  NaN
# 2699                           1.33                                 0.44
# 2726                           0.18                                  NaN
# 2756                           9.02                                 0.26
# 3192                           5.55                                 3.09
# 3254                           5.28                                 2.53
# 3374                           4.63                                 3.20
# 3485                            NaN                                  NaN
# 3614                          13.02                                 7.45
# 3755                           5.52                                 2.43
# 3817                           5.79                                 2.46
# 3828                           0.11                                 0.11
# 3830                           0.04                                  NaN
# 3974                           4.69                                 2.44
# 4059                           8.00                                 1.84
# 4092                           0.01                                  NaN
# 4145                            NaN                                  NaN
# 4289                          14.11                                 6.76
# 4379                           0.08                                  NaN
#
#       daily_vaccinations_per_million  \
# 170                            744.0
# 182                            132.0
# 230                           2126.0
# 317                           2069.0
# 573                           1053.0
# 633                           2059.0
# 700                           1418.0
# 827                           3400.0
# 895                            169.0
# 1122                          1313.0
# 1470                          2402.0
# 1593                          1719.0
# 1701                          2645.0
# 1806                          3075.0
# 1865                          2696.0
# 1908                           342.0
# 1954                           301.0
# 2056                          4598.0
# 2126                         13139.0
# 2188                          1578.0
# 2198                            27.0
# 2359                          1230.0
# 2373                           288.0
# 2476                          2456.0
# 2570                          9348.0
# 2699                           772.0
# 2726                           296.0
# 2756                          4111.0
# 3192                          2299.0
# 3254                          2499.0
# 3374                          1394.0
# 3485                           498.0
# 3614                          4871.0
# 3755                          1955.0
# 3817                          1967.0
# 3828                           138.0
# 3830                           361.0
# 3974                          1907.0
# 4059                          3281.0
# 4092                            33.0
# 4145                          6738.0
# 4289                          4643.0
# 4379                           118.0
#
#                                                vaccines  \
# 170                                           Sputnik V
# 182                                     Pfizer/BioNTech
# 230        Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 317       Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V
# 573                         Oxford/AstraZeneca, Sinovac
# 633        Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 700                            Moderna, Pfizer/BioNTech
# 827                            Pfizer/BioNTech, Sinovac
# 895                                     Pfizer/BioNTech
# 1122       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 1470       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 1593       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 1701       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 1806  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, ...
# 1865       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 1908                        Covaxin, Oxford/AstraZeneca
# 1954                                            Sinovac
# 2056                Oxford/AstraZeneca, Pfizer/BioNTech
# 2126                           Moderna, Pfizer/BioNTech
# 2188       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 2198                                    Pfizer/BioNTech
# 2359       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 2373                                    Pfizer/BioNTech
# 2476       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 2570                                 Oxford/AstraZeneca
# 2699     Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V
# 2726                                          Sputnik V
# 2756              Oxford/AstraZeneca, Sinopharm/Beijing
# 3192       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 3254                           Moderna, Pfizer/BioNTech
# 3374       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 3485                                    Pfizer/BioNTech
# 3614      Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V
# 3755                                    Pfizer/BioNTech
# 3817                Oxford/AstraZeneca, Pfizer/BioNTech
# 3828                                    Johnson&Johnson
# 3830                                          Sputnik V
# 3974                Oxford/AstraZeneca, Pfizer/BioNTech
# 4059                                            Sinovac
# 4092                                 Oxford/AstraZeneca
# 4145  Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 4289                           Moderna, Pfizer/BioNTech
# 4379                                  Sinopharm/Beijing
#
#                                             source_name  \
# 170                                  Ministry of Health
# 182        Government of Australia via covidlive.com.au
# 230                                  Ministry of Health
# 317                                  Ministry of Health
# 573         Regional governments via Coronavirus Brasil
# 633                                  Ministry of Health
# 700                                Government of Canada
# 827     Department of Statistics and Health Information
# 895                                  Ministry of Health
# 1122                                 Ministry of Health
# 1470           Finnish Institute for Health and Welfare
# 1593                               Robert Koch Institut
# 1701                                 Ministry of Health
# 1806                              Government of Hungary
# 1865                              Directorate of Health
# 1908                                 Ministry of Health
# 1954                                 Ministry of Health
# 2056                             Isle of Man Government
# 2126                               Government of Israel
# 2188  Extraordinary commissioner for the Covid-19 em...
# 2198             Ministry of Health, Labour and Welfare
# 2359                            National Health Service
# 2373                              Government of Lebanon
# 2476                                 Ministry of Health
# 2570                         Presidency of the Maldives
# 2699                                Secretary of Health
# 2726                           Government of Montenegro
# 2756                                 Ministry of Health
# 3192                                 Ministry of Health
# 3254  General Directorate of Health via Data Science...
# 3374                              Government of Romania
# 3485                               Saudi Health Council
# 3614                               Government of Serbia
# 3755                                 Ministry of Health
# 3817  National Institute of Public Health, via Sledi...
# 3828                                 Ministry of Health
# 3830   Korea Centers for Disease Control and Prevention
# 3974                     Public Health Agency of Sweden
# 4059              COVID-19 Vaccine Information Platform
# 4092                                 Ministry of Health
# 4145  National Emergency Crisis and Disaster Managem...
# 4289         Centers for Disease Control and Prevention
# 4379                                 Ministry of Health
#
#                                          source_website
# 170   http://datos.salud.gob.ar/dataset/vacunas-cont...
# 182               https://covidlive.com.au/vaccinations
# 230   https://info.gesundheitsministerium.gv.at/open...
# 317   https://twitter.com/MOH_Bahrain/status/1365406...
# 573                  https://coronavirusbra1.github.io/
# 633                https://coronavirus.bg/bg/statistika
# 700   https://health-infobase.canada.ca/covid-19/vac...
# 827                      https://www.gob.cl/yomevacuno/
# 895   https://twitter.com/MinSaludCol/status/1365433...
# 1122       https://onemocneni-aktualne.mzcr.cz/covid-19
# 1470  https://www.thl.fi/episeuranta/rokotukset/koro...
# 1593                          https://impfdashboard.de/
# 1701      https://www.data.gov.gr/datasets/mdg_emvolio/
# 1806  https://koronavirus.gov.hu/cikkek/4948-fovel-e...
# 1865  https://www.covid.is/tolulegar-upplysingar-bol...
# 1908  https://pib.gov.in/PressReleseDetailm.aspx?PRI...
# 1954                          https://www.kemkes.go.id/
# 2056  https://covid19.gov.im/general-information/cov...
# 2126  https://datadashboard.health.gov.il/COVID-19/g...
# 2188  https://github.com/italia/covid19-opendata-vac...
# 2198  https://www.mhlw.go.jp/stf/seisakunitsuite/bun...
# 2359  https://data.gov.lv/dati/eng/dataset/covid19-v...
# 2373   https://impact.cib.gov.lb/home/dashboard/vaccine
# 2476  https://ls-osp-sdg.maps.arcgis.com/apps/opsdas...
# 2570  https://twitter.com/HPA_MV/status/136535101138...
# 2699  https://www.gob.mx/salud/prensa/085-ninguna-en...
# 2726                       https://www.covidodgovor.me/
# 2756  http://www.covidmaroc.ma/Documents/BULLETIN/26...
# 3192  https://www.gov.pl/web/szczepimysie/raport-szc...
# 3254          https://github.com/dssg-pt/covid19pt-data
# 3374  https://vaccinare-covid.gov.ro/wp-content/uplo...
# 3485                        https://covid19.moh.gov.sa/
# 3614  https://www.srbija.gov.rs/vest/en/168513/new-m...
# 3755                         https://covid-19.nczisk.sk
# 3817            https://covid-19.sledilnik.org/en/stats
# 3828  https://twitter.com/DrZweliMkhize/status/13653...
# 3830                             http://ncv.kdca.go.kr/
# 3974  https://www.folkhalsomyndigheten.se/smittskydd...
# 4059                  https://covid19asi.saglik.gov.tr/
# 4092                https://vaccination.covid19.gov.ua/
# 4145                     http://covid19.ncema.gov.ae/en
# 4289  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 4379  https://twitter.com/MoHCCZim/status/1365400469...

# %% [markdown]
# # Atenção!
# Perceba que o dataset filtrado pela ultima data retornou (43,15) ou seja 43 linhas e 15 colunas. Isso não esta certo! Pois verificamos que temos 112 países no dataset original.
#
# Dessa forma, ao filtrar pela última data estamos excluindo registros de outros países que não foram ainda computados na última coleta.
#
# Para resolver esse problema, temos que selecionar o último registro de data cada país. Assim não vamos deixar nenhum país de fora.
#
# Vamos fazer um agrupamento do pais e selecionar a última data de atualização que foi realizada

# %%
dataframe.groupby('country')['date'].max().sort_values(ascending=False)
# Out:
# country
# Zimbabwe           2021-02-26
# Hungary            2021-02-26
# Lebanon            2021-02-26
# Romania            2021-02-26
# Portugal           2021-02-26
#                       ...
# Myanmar            2021-02-02
# Egypt              2021-01-30
# Greenland          2021-01-27
# Northern Cyprus    2021-01-22
# Monaco             2021-01-18
# Name: date, Length: 112, dtype: object

# %% [markdown]
# Agora vimos que existem de fato países que não possuem a atualização da ultima data da coleta.
# Dessa forma, temos que procurar uma outra maneira para obter esses dados.
# A variável total_vaccinations contém o total de vacinações naquele país. Ou seja, podemos utilizar ele como parâmetro  para buscar a última data de coleta.
# Desta forma, vamos agrupar por país e pegar o valor máximo obtido nessa variável.

# %%
dataframe.groupby('country')['total_vaccinations'].max().sort_values(ascending=False)
# Out:
# country
# United States          70454064.0
# China                  40520000.0
# United Kingdom         19913592.0
# England                16785841.0
# India                  13756940.0
#                           ...
# Paraguay                   1000.0
# New Zealand                1000.0
# Trinidad and Tobago         440.0
# Venezuela                   157.0
# Saint Helena                107.0
# Name: total_vaccinations, Length: 112, dtype: float64

# %% [markdown]
# Vamos então criar a lista com os TOP 10 países

# %%
imunizados_por_pais = dataframe.groupby('country')['total_vaccinations'].max().sort_values(ascending=False)
imunizados_por_pais
# Out:
# country
# United States          70454064.0
# China                  40520000.0
# United Kingdom         19913592.0
# England                16785841.0
# India                  13756940.0
#                           ...
# Paraguay                   1000.0
# New Zealand                1000.0
# Trinidad and Tobago         440.0
# Venezuela                   157.0
# Saint Helena                107.0
# Name: total_vaccinations, Length: 112, dtype: float64

# %%
type(imunizados_por_pais)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Percebam que efetuar uma operação, o seu resultado se transforma em uma série pandas.
#
# Uma Série Pandas se caracterizada por um array unidimensional capaz de armazenar qualquer tipo de dados com rótulos ou índice de eixo. Um exemplo de um objeto Series é uma coluna de um DataFrame.
#
# Para transformar novamente em um dataframe temos que usar o comando to_frame() e resetar o index.

# %%
imunizados = imunizados_por_pais.to_frame().reset_index()
imunizados
# Out:
#                  country  total_vaccinations
# 0          United States          70454064.0
# 1                  China          40520000.0
# 2         United Kingdom          19913592.0
# 3                England          16785841.0
# 4                  India          13756940.0
# ..                   ...                 ...
# 107             Paraguay              1000.0
# 108          New Zealand              1000.0
# 109  Trinidad and Tobago               440.0
# 110            Venezuela               157.0
# 111         Saint Helena               107.0
#
# [112 rows x 2 columns]

# %% [markdown]
# Pronto! Agora temos a relação do número total de imunizados por pais.
#
# Vamos utilizar o metodo sort_values na variável total_vaccinations para ordenar e o parâmetro ascending como False para ordenar do maior para o menor. Além disso, vamos selecionar os 10 primeiros países

# %%
imunizados.sort_values('total_vaccinations',ascending=False).head(10)
# Out:
#                 country  total_vaccinations
# 0         United States          70454064.0
# 1                 China          40520000.0
# 2        United Kingdom          19913592.0
# 3               England          16785841.0
# 4                 India          13756940.0
# 5                Turkey           8298805.0
# 6                Brazil           8101787.0
# 7                Israel           7957787.0
# 8  United Arab Emirates           5933299.0
# 9               Germany           5910537.0

# %% [markdown]
# ## 2. Qual vacina é a mais utilizada no mundo?

# %% [markdown]
# Para descobrir qual vacina mais utilizada no mundo devemos criar um dataframe contendo as vacinas utilizadas por pais. Com isso, vamos ter uma relação com todas as vacinas por pais em uma determinada data.

# %%
vacinas_por_pais = dataframe[['country', 'date', 'vaccines']]
vacinas_por_pais
# Out:
#        country        date           vaccines
# 0      Albania  2021-01-10    Pfizer/BioNTech
# 1      Albania  2021-01-11    Pfizer/BioNTech
# 2      Albania  2021-01-12    Pfizer/BioNTech
# 3      Albania  2021-01-13    Pfizer/BioNTech
# 4      Albania  2021-01-14    Pfizer/BioNTech
# ...        ...         ...                ...
# 4375  Zimbabwe  2021-02-22  Sinopharm/Beijing
# 4376  Zimbabwe  2021-02-23  Sinopharm/Beijing
# 4377  Zimbabwe  2021-02-24  Sinopharm/Beijing
# 4378  Zimbabwe  2021-02-25  Sinopharm/Beijing
# 4379  Zimbabwe  2021-02-26  Sinopharm/Beijing
#
# [4380 rows x 3 columns]

# %% [markdown]
# Ótimo! Agora vamos agrupar as vacinas e contar os pais apenas uma vez. Se no datasert tiver um país utilizando duas vacinas, ele vai ser contato duas vezes.

# %%
vacinas_por_pais.groupby('vaccines')['country'].nunique().sort_values(ascending=False)
# Out:
# vaccines
# Pfizer/BioNTech                                                                       26
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          20
# Oxford/AstraZeneca                                                                    15
# Sputnik V                                                                             11
# Oxford/AstraZeneca, Pfizer/BioNTech                                                   10
# Moderna, Pfizer/BioNTech                                                               7
# Sinopharm/Beijing                                                                      6
# Sinovac                                                                                2
# Oxford/AstraZeneca, Sinopharm/Beijing                                                  2
# Pfizer/BioNTech, Sinovac                                                               2
# Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                                          2
# Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac                                            1
# Covaxin, Oxford/AstraZeneca                                                            1
# Oxford/AstraZeneca, Sputnik V                                                          1
# Oxford/AstraZeneca, Sinovac                                                            1
# Johnson&Johnson                                                                        1
# Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V                                         1
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V     1
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V             1
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V                                       1
# Name: country, dtype: int64

# %%
vacinas_pais = dataframe.groupby('country')['vaccines'].unique()
vacinas_pais = vacinas_pais.to_frame().reset_index()

# %% [markdown]
# Temos a relação entre as vacinas mais utilizadas no mundo. Percebam que a vacina Pfizer/BioNTech contém 26 paises fazendo o seu uso.

# %% [markdown]
# ## 3. Qual o país possui o maior número de vacinados por dia?
#
# Para obter essa resposta temos que analisar a variável *daily_vaccinations*.

# %%
dataframe.groupby('country')['daily_vaccinations'].max().sort_values(ascending=False)
# Out:
# country
# China                  1916190.0
# United States          1716311.0
# India                   472428.0
# United Kingdom          445204.0
# Turkey                  435596.0
#                          ...
# Andorra                    100.0
# Trinidad and Tobago         63.0
# Venezuela                   31.0
# Greenland                    NaN
# Saint Helena                 NaN
# Name: daily_vaccinations, Length: 112, dtype: float64

# %% [markdown]
# ## 4. Qual a média de vacinação de vacinação por pais?

# %%
media_pais = dataframe.groupby('country')['daily_vaccinations'].mean().sort_values(ascending=False)
media_pais = media_pais.to_frame().reset_index()
media_pais
# Out:
#             country  daily_vaccinations
# 0     United States       961578.338235
# 1             China       623616.000000
# 2             India       298508.476190
# 3    United Kingdom       255473.256757
# 4           England       215682.081081
# ..              ...                 ...
# 107         Andorra           62.000000
# 108   Liechtenstein           52.619048
# 109       Venezuela           31.000000
# 110       Greenland                 NaN
# 111    Saint Helena                 NaN
#
# [112 rows x 2 columns]

# %% [markdown]
# Pronto! Todas as perguntas respondidadas.
#
# Um dos trabalhos de um cientista de dados é extrair, limpar, tratar e gerar novos dados.
#
# Geramos alguns dataframes das perguntas que criamos.
# 1. imunizados
# 2. vacinas_por_pais
# 3. media_pais
#
# Agora vamos criar uma nova base de dados utilizando os dados que tratamos anteriormente.

# %%
# Renomeando novas colunas dos datas
#Vamos iniciar alterando o nome de algumas colunas

media_pais = media_pais.rename(columns={'country': 'pais','daily_vaccinations': 'media_vacinacao'})

# %%
media_pais
# Out:
#                pais  media_vacinacao
# 0     United States    961578.338235
# 1             China    623616.000000
# 2             India    298508.476190
# 3    United Kingdom    255473.256757
# 4           England    215682.081081
# ..              ...              ...
# 107         Andorra        62.000000
# 108   Liechtenstein        52.619048
# 109       Venezuela        31.000000
# 110       Greenland              NaN
# 111    Saint Helena              NaN
#
# [112 rows x 2 columns]

# %%
vacinas_pais = vacinas_pais.rename(columns={'country': 'pais', 'vaccines': 'vacina_utilizada'})
vacinas_pais[:5]
# Out:
#         pais      vacina_utilizada
# 0    Albania     [Pfizer/BioNTech]
# 1    Algeria           [Sputnik V]
# 2    Andorra     [Pfizer/BioNTech]
# 3   Anguilla  [Oxford/AstraZeneca]
# 4  Argentina           [Sputnik V]

# %%
imunizados = imunizados.rename(columns={'country': 'pais', 'total_vaccinations': 'Imunizados'})
imunizados[:5]
# Out:
#              pais  Imunizados
# 0   United States  70454064.0
# 1           China  40520000.0
# 2  United Kingdom  19913592.0
# 3         England  16785841.0
# 4           India  13756940.0

# %% [markdown]
# # Criando um novo dataset
#
# Para criar um novo dateset (conjunto de dados), vamos utilizar a função merge. Essa função vai comparar os campos das tabelas que são chaves iguais, como o nome do pais e realizar uma junção entre as tabelas. Assim vamos ter todos os dados tratados em uma única tabela.

# %%
dados_tratados = pd.merge(imunizados, media_pais, how='inner')

# %%
dados_tratados = pd.merge(dados_tratados, vacinas_pais)
dados_tratados
# Out:
#                     pais  Imunizados  media_vacinacao  \
# 0          United States  70454064.0    961578.338235
# 1                  China  40520000.0    623616.000000
# 2         United Kingdom  19913592.0    255473.256757
# 3                England  16785841.0    215682.081081
# 4                  India  13756940.0    298508.476190
# ..                   ...         ...              ...
# 107             Paraguay      1000.0       250.000000
# 108          New Zealand      1000.0       108.000000
# 109  Trinidad and Tobago       440.0        63.000000
# 110            Venezuela       157.0        31.000000
# 111         Saint Helena       107.0              NaN
#
#                                   vacina_utilizada
# 0                       [Moderna, Pfizer/BioNTech]
# 1    [Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac]
# 2            [Oxford/AstraZeneca, Pfizer/BioNTech]
# 3            [Oxford/AstraZeneca, Pfizer/BioNTech]
# 4                    [Covaxin, Oxford/AstraZeneca]
# ..                                             ...
# 107                                    [Sputnik V]
# 108                              [Pfizer/BioNTech]
# 109                           [Oxford/AstraZeneca]
# 110                                    [Sputnik V]
# 111                           [Oxford/AstraZeneca]
#
# [112 rows x 4 columns]

# %% [markdown]
# Podemos também realizar de forma direta conforme o script abaixo. veja que temos que fazer cada junção de forma separada. Sempre de dentro para fora.

# %%
pd.merge(pd.merge(imunizados, media_pais), vacinas_pais)

# %% [markdown]
# # Exportando dados tratados
# Pronto! Agora que criamos o nosso dataset vamos exportar ele para um arquivo txt.

# %%
dados_tratados.to_csv('estatistica_pais_2.csv', index= True, sep = ';')

# %%
dados_tratados.to_json('estatistica_2.json', orient = 'records')
